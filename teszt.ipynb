# %%
import eyecolors as eye

pop = eye.simulating_first_population()
sim = eye.simulating_generations(pop)
eye.plot_one_simulaiton(sim)

sim_futures = eye.monte_carlo(pop)
eye.plot_eye_color_proportions_all_runs(sim_futures)
# Out:
# ...
# simulating futures...: 100%|██████████| 10/10 [00:58<00:00,  5.86s/it]
